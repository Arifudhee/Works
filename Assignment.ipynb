# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the dataset to python environment.

# %%
data = pd.read_excel(r'C:\Users\FZ\Downloads\iris.xls')

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # mean of each column of the dataset

# %%
data.SL.mean()
# Out:
# 5.843333333333335

# %%
data.SW.mean()
# Out:
# 3.0540000000000007

# %%
data.PL.mean()
# Out:
# 3.7586666666666693

# %%
data.PW.mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# # null values present in the dataset

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # visualizations.

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data['SL'], data['PL'])
plt.title('Plot of SL vs PL')
plt.xlabel('SL')
plt.ylabel('PL')
plt.show()

# %%
plt.scatter(data['SW'], data['PW'])
plt.title('Plot of SW vs PW')
plt.xlabel('SW')
plt.ylabel('PW')
plt.show()

# %%
plt.bar(data['SL'], data['PL'])
plt.xlabel('SL')
plt.ylabel('PL')
plt.show()

# %%
plt.bar(data['SW'], data['PW'])
plt.xlabel('SW')
plt.ylabel('PW')
plt.show()

# %%
plt.boxplot(data['SL'])
plt.show()

# %%
plt.boxplot(data[['SW','PW']])
plt.show()
